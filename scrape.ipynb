# %%
from bs4 import BeautifulSoup
import requests
import numpy as np 
import pandas as pd

from airbnb_scraper_utils import *

# %%
page_url = 'https://www.airbnb.com/s/Fayetteville--WV/homes?adults=8&place_id=ChIJl0eofsW-TogRkhwq11xezP0&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Fayetteville%2C%20WV&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&ne_lat=38.49412295904822&ne_lng=-79.86391165427358&sw_lat=37.385109374248714&sw_lng=-81.71236136130483&zoom=10&search_by_map=true&search_type=user_map_move&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header'

listings = scrape_listings(page_url)
listings_df = parse_listings(listings)

# %%
month = int(5)

listings_df.loc[:,'month'] = month

# %%
listings_df
# Out:
#                                                 title  price  rating  guests  \
# 0      Adventure House Of the New River National Park    220    4.86       8
# 0                          Spacious 5 BR, 2 Bath Home    460     NaN      10
# 0    The Grateful Bed : Convenient and Roomy NRG Find    189    4.97      12
# 0                                    Shady Lane Oasis    650    4.78      12
# 0                                       Backyard Envy    439    4.93      10
# ..                                                ...    ...     ...     ...
# 0            RV Site Near Hatfield-McCoy Trail (40ft)     65     NaN       8
# 0   Stemwinder #3:  3 BEDROOMS PLUS Bonus Sleeping...    399    4.40      11
# 0                              Camping at The Lookout    150     NaN       8
# 0           RV Site near Hatfield-McCoy Trails (30ft)     55     NaN       8
# 0            RV Site Near Hatfield-McCoy Trail (40ft)     65     NaN       8
#
# ...

# %%
# print(f"Title: {listings[2].find('span', {'class':'ts5gl90'}).text}")
# type_loc = listings[2].find('div',{'class': 'mj1p6c8'}).text.split(' in ')
# type_loc

# listing_type = type_loc[0]
# listing_loc = type_loc[1]
# print(f"Type: {listing_type}")
# print(f"Location: {listing_loc}")

# rating_string = listings[2].find('div', {'class':'sglmc5a'}).text.split()

print(listings[2].find('span', attrs={'class':'bi6b9fr'}))
# rating = float(rating_string[2])
# n_reviews = int(rating_string[1].replace('(',''))
# print(f"Rating: {rating}")
# print(f"Number of Reviews: {n_reviews}")


# price = int(listings[2].find('div', {'class':'p1qe1cgb'}).text.split()[0].replace('$',''))
# Out:
# None

# %%
listing_counts = listings[1].find('div', attrs={'class':'i1wgresd'}).findAll('span',{'class':'mp2hv9t'})
# for count in listing_counts:
#     print(count)
#     if count.contains('guests'):
#         print('yup')
#     else:
#         print('nope')

# [s for s in listing_counts if 'guests' in s]
# guests = listing_counts[0]
# bedrooms = listing_counts[1]
# beds = listing_counts[2]
# baths = listing_counts[3]

# %%
# listing_counts[0].string
# for count in listing_counts:
#     count_string = count.string
#     if 'guests' in count_string:
#         print(count_string)
# [(s.string if 'guests' in s.string else np.nan) for s in listing_counts ]

# %%
import re
guests = [int(re.sub('[^\d\.]','', s.string)) for s in listing_counts if 'guests' in s.string]
bedrooms = [int(re.sub('[^\d\.]','', s.string)) for s in listing_counts if 'bedrooms' in s.string]
beds = [int(re.sub('[^\d\.]','', s.string)) for s in listing_counts if 'beds' in s.string]
baths = [float(re.sub('[^\d\.]','', s.string)) for s in listing_counts if 'baths' in s.string]
test =  [int(re.sub('[^\d\.]','', s.string)) for s in listing_counts if 'test' in s.string]
if len(guests) < 1:
    guests = [np.nan]
if len(bedrooms) < 1:
    bedrooms = [np.nan]
if len(beds) < 1:
    beds = [np.nan]
if len(baths) < 1:
    baths = [np.nan]
if len(test) < 1:
    test = [np.nan]

# %%
bedrooms
# Out:
# [4]

# %%
url1 = 'https://www.airbnb.com/s/Fayetteville--WV/homes?adults=8&place_id=ChIJl0eofsW-TogRkhwq11xezP0&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Fayetteville%2C%20WV&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&ne_lat=38.17039223264452&ne_lng=-80.71981527976186&sw_lat=37.61551918210437&sw_lng=-81.49915793112905&zoom=11&search_by_map=true&search_type=user_map_move&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header'
url2 = 'https://www.airbnb.com/s/Fayetteville--WV/homes?adults=8&place_id=ChIJl0eofsW-TogRkhwq11xezP0&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Fayetteville%2C%20WV&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&ne_lat=38.17039223264452&ne_lng=-80.71981527976186&sw_lat=37.61551918210437&sw_lng=-81.49915793112905&zoom=11&search_by_map=true&search_type=user_map_move&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&federated_search_session_id=d380a867-b5f5-43e1-8705-b7c42340a972&pagination_search=true&items_offset=20&section_offset=2'
url3 = 'https://www.airbnb.com/s/Fayetteville--WV/homes?adults=8&place_id=ChIJl0eofsW-TogRkhwq11xezP0&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Fayetteville%2C%20WV&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&ne_lat=38.17039223264452&ne_lng=-80.71981527976186&sw_lat=37.61551918210437&sw_lng=-81.49915793112905&zoom=11&search_by_map=true&search_type=user_map_move&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&federated_search_session_id=d380a867-b5f5-43e1-8705-b7c42340a972&pagination_search=true&items_offset=40&section_offset=2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3347/4204751954.py in <module>
#       1 url1 = 'https://www.airbnb.com/s/Fayetteville--WV/homes?adults=8&place_id=ChIJl0eofsW-TogRkhwq11xezP0&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Fayetteville%2C%20WV&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&ne_lat=38.17039223264452&ne_lng=-80.71981527976186&sw_lat=37.61551918210437&sw_lng=-81.49915793112905&zoom=11&search_by_map=true&search_type=user_map_move&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header'
# ...

# %%
url4 = 'https://www.airbnb.com/s/Fayetteville--WV/homes?place_id=ChIJl0eofsW-TogRkhwq11xezP0&refinement_paths%5B%5D=%2Fhomes&checkin=2022-05-13&checkout=2022-05-15&adults=0&children=0&infants=0&pets=0&search_type=AUTOSUGGEST&pagination_search=true&items_offset=20&section_offset=2'
url5 = 'https://www.airbnb.com/s/Fayetteville--WV/homes?place_id=ChIJl0eofsW-TogRkhwq11xezP0&refinement_paths%5B%5D=%2Fhomes&checkin=2022-05-13&checkout=2022-05-15&search_type=AUTOSUGGEST&tab_id=home_tab&query=Fayetteville%2C%20WV&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&federated_search_session_id=ca2322c7-cf57-4bba-9cf2-0f30bb592955&pagination_search=true&items_offset=20&section_offset=2'
